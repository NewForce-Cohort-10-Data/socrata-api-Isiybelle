# %% [markdown]
# In this exercise, you'll redo the data gathering phase of the UNData Exploration project by using APIs instead of downloading csv files.
#
# You'll make use of the World Bank Indicators API. Note that this API does not require an API key. Before attempting the exercise, it would be a good idea to skim through the Documentation page and to check out the Basic Call Structure article.

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# Use the API to get all available data for the GDP per capita, PPP (constant 2017 international $) indicator. Hint: this indicator has code "NY.GDP.PCAP.PP.KD". Adjust the query parameters so that you can retrieve all available rows. Convert the results to a DataFrame.

# %%
# vari = 'all/indicator/NY.GDP.PCAP.PP.KD?date=2017?format=json'
url1 = 'https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD'
params = {
    'date' : '2017',
    'format' : 'json'}

response = requests.get(url1, params = params)
response
# Out:
# <Response [200]>

# %%
nygdp = pd.json_normalize(response.json()[1])
nygdp = nygdp.drop(columns = ['unit', 'obs_status', 'decimal'])
nygdp
# Out:
#    countryiso3code  date         value       indicator.id  \
# 0              AFE  2017   4085.879143  NY.GDP.PCAP.PP.KD
# 1              AFW  2017   4709.645461  NY.GDP.PCAP.PP.KD
# 2              ARB  2017  16054.975876  NY.GDP.PCAP.PP.KD
# 3              CSS  2017  19132.939321  NY.GDP.PCAP.PP.KD
# 4              CEB  2017  34765.911440  NY.GDP.PCAP.PP.KD
# 5              EAR  2017  10143.684384  NY.GDP.PCAP.PP.KD
# 6              EAS  2017  18492.084823  NY.GDP.PCAP.PP.KD
# 7              EAP  2017  14861.366454  NY.GDP.PCAP.PP.KD
# 8              TEA  2017  15028.621872  NY.GDP.PCAP.PP.KD
# 9              EMU  2017  52727.943724  NY.GDP.PCAP.PP.KD
# 10             ECS  2017  40189.716777  NY.GDP.PCAP.PP.KD
# 11             ECA  2017  19694.866584  NY.GDP.PCAP.PP.KD
# 12             TEC  2017  27003.309029  NY.GDP.PCAP.PP.KD
# 13             EUU  2017  49573.915785  NY.GDP.PCAP.PP.KD
# 14             FCS  2017   5566.078053  NY.GDP.PCAP.PP.KD
# 15             HPC  2017   2938.856554  NY.GDP.PCAP.PP.KD
# 16                  2017  52534.313296  NY.GDP.PCAP.PP.KD
# 17             IBD  2017  14659.970661  NY.GDP.PCAP.PP.KD
# 18             IBT  2017  11979.534023  NY.GDP.PCAP.PP.KD
# 19             IDB  2017   5422.635736  NY.GDP.PCAP.PP.KD
# 20             IDX  2017   3843.099452  NY.GDP.PCAP.PP.KD
# 21             IDA  2017   4360.712358  NY.GDP.PCAP.PP.KD
# 22             LTE  2017  18985.622069  NY.GDP.PCAP.PP.KD
# 23             LCN  2017  18700.381642  NY.GDP.PCAP.PP.KD
# 24             LAC  2017  18049.408221  NY.GDP.PCAP.PP.KD
# 25             TLA  2017  18606.555336  NY.GDP.PCAP.PP.KD
# 26             LDC  2017   3543.175816  NY.GDP.PCAP.PP.KD
# 27             LMY  2017  11005.938541  NY.GDP.PCAP.PP.KD
# 28                  2017   2331.752179  NY.GDP.PCAP.PP.KD
# 29                  2017   7105.220602  NY.GDP.PCAP.PP.KD
# 30             MEA  2017  18112.735171  NY.GDP.PCAP.PP.KD
# 31             MNA  2017  12415.939810  NY.GDP.PCAP.PP.KD
# 32             TMN  2017  12485.176080  NY.GDP.PCAP.PP.KD
# 33             MIC  2017  11987.709217  NY.GDP.PCAP.PP.KD
# 34             NAC  2017  65459.338144  NY.GDP.PCAP.PP.KD
# 35                  2017           NaN  NY.GDP.PCAP.PP.KD
# 36             OED  2017  48695.960343  NY.GDP.PCAP.PP.KD
# 37             OSS  2017  25879.609938  NY.GDP.PCAP.PP.KD
# 38             PSS  2017   7371.408692  NY.GDP.PCAP.PP.KD
# 39             PST  2017  53748.229692  NY.GDP.PCAP.PP.KD
# 40             PRE  2017   4190.105661  NY.GDP.PCAP.PP.KD
# 41             SST  2017  22367.284994  NY.GDP.PCAP.PP.KD
# 42             SAS  2017   6885.443570  NY.GDP.PCAP.PP.KD
# 43             TSA  2017   6885.443570  NY.GDP.PCAP.PP.KD
# 44             SSF  2017   4338.833030  NY.GDP.PCAP.PP.KD
# 45             SSA  2017   4336.420250  NY.GDP.PCAP.PP.KD
# 46             TSS  2017   4338.833030  NY.GDP.PCAP.PP.KD
# 47                  2017  17052.640927  NY.GDP.PCAP.PP.KD
# 48             WLD  2017  18510.565889  NY.GDP.PCAP.PP.KD
# 49             AFG  2017   2952.998916  NY.GDP.PCAP.PP.KD
#
#                                       indicator.value country.id  \
# 0   GDP per capita, PPP (constant 2021 internation...         ZH
# 1   GDP per capita, PPP (constant 2021 internation...         ZI
# 2   GDP per capita, PPP (constant 2021 internation...         1A
# 3   GDP per capita, PPP (constant 2021 internation...         S3
# 4   GDP per capita, PPP (constant 2021 internation...         B8
# 5   GDP per capita, PPP (constant 2021 internation...         V2
# 6   GDP per capita, PPP (constant 2021 internation...         Z4
# 7   GDP per capita, PPP (constant 2021 internation...         4E
# 8   GDP per capita, PPP (constant 2021 internation...         T4
# 9   GDP per capita, PPP (constant 2021 internation...         XC
# 10  GDP per capita, PPP (constant 2021 internation...         Z7
# 11  GDP per capita, PPP (constant 2021 internation...         7E
# 12  GDP per capita, PPP (constant 2021 internation...         T7
# 13  GDP per capita, PPP (constant 2021 internation...         EU
# 14  GDP per capita, PPP (constant 2021 internation...         F1
# 15  GDP per capita, PPP (constant 2021 internation...         XE
# 16  GDP per capita, PPP (constant 2021 internation...         XD
# 17  GDP per capita, PPP (constant 2021 internation...         XF
# 18  GDP per capita, PPP (constant 2021 internation...         ZT
# 19  GDP per capita, PPP (constant 2021 internation...         XH
# 20  GDP per capita, PPP (constant 2021 internation...         XI
# 21  GDP per capita, PPP (constant 2021 internation...         XG
# 22  GDP per capita, PPP (constant 2021 internation...         V3
# 23  GDP per capita, PPP (constant 2021 internation...         ZJ
# 24  GDP per capita, PPP (constant 2021 internation...         XJ
# 25  GDP per capita, PPP (constant 2021 internation...         T2
# 26  GDP per capita, PPP (constant 2021 internation...         XL
# 27  GDP per capita, PPP (constant 2021 internation...         XO
# 28  GDP per capita, PPP (constant 2021 internation...         XM
# 29  GDP per capita, PPP (constant 2021 internation...         XN
# 30  GDP per capita, PPP (constant 2021 internation...         ZQ
# 31  GDP per capita, PPP (constant 2021 internation...         XQ
# 32  GDP per capita, PPP (constant 2021 internation...         T3
# 33  GDP per capita, PPP (constant 2021 internation...         XP
# 34  GDP per capita, PPP (constant 2021 internation...         XU
# 35  GDP per capita, PPP (constant 2021 internation...         XY
# 36  GDP per capita, PPP (constant 2021 internation...         OE
# 37  GDP per capita, PPP (constant 2021 internation...         S4
# 38  GDP per capita, PPP (constant 2021 internation...         S2
# 39  GDP per capita, PPP (constant 2021 internation...         V4
# 40  GDP per capita, PPP (constant 2021 internation...         V1
# 41  GDP per capita, PPP (constant 2021 internation...         S1
# 42  GDP per capita, PPP (constant 2021 internation...         8S
# 43  GDP per capita, PPP (constant 2021 internation...         T5
# 44  GDP per capita, PPP (constant 2021 internation...         ZG
# 45  GDP per capita, PPP (constant 2021 internation...         ZF
# 46  GDP per capita, PPP (constant 2021 internation...         T6
# 47  GDP per capita, PPP (constant 2021 internation...         XT
# 48  GDP per capita, PPP (constant 2021 internation...         1W
# 49  GDP per capita, PPP (constant 2021 internation...         AF
#
#                                         country.value
# 0                         Africa Eastern and Southern
# 1                          Africa Western and Central
# 2                                          Arab World
# 3                              Caribbean small states
# 4                      Central Europe and the Baltics
# 5                          Early-demographic dividend
# 6                                 East Asia & Pacific
# 7         East Asia & Pacific (excluding high income)
# 8          East Asia & Pacific (IDA & IBRD countries)
# 9                                           Euro area
# 10                              Europe & Central Asia
# 11      Europe & Central Asia (excluding high income)
# 12       Europe & Central Asia (IDA & IBRD countries)
# 13                                     European Union
# 14           Fragile and conflict affected situations
# 15             Heavily indebted poor countries (HIPC)
# 16                                        High income
# 17                                          IBRD only
# 18                                   IDA & IBRD total
# 19                                          IDA blend
# 20                                           IDA only
# 21                                          IDA total
# 22                          Late-demographic dividend
# 23                          Latin America & Caribbean
# 24  Latin America & Caribbean (excluding high income)
# 25  Latin America & the Caribbean (IDA & IBRD coun...
# 26       Least developed countries: UN classification
# 27                                Low & middle income
# 28                                         Low income
# 29                                Lower middle income
# 30                         Middle East & North Africa
# 31  Middle East & North Africa (excluding high inc...
# 32  Middle East & North Africa (IDA & IBRD countries)
# 33                                      Middle income
# 34                                      North America
# 35                                     Not classified
# 36                                       OECD members
# 37                                 Other small states
# 38                        Pacific island small states
# 39                          Post-demographic dividend
# 40                           Pre-demographic dividend
# 41                                       Small states
# 42                                         South Asia
# 43                            South Asia (IDA & IBRD)
# 44                                 Sub-Saharan Africa
# 45         Sub-Saharan Africa (excluding high income)
# 46          Sub-Saharan Africa (IDA & IBRD countries)
# 47                                Upper middle income
# 48                                              World
# 49                                        Afghanistan

# %% [markdown]
# Now, use the API to get all available data for Life expectancy at birth, total (years). This indicator has code "SP.DYN.LE00.IN". Again, convert the results to a DataFrame.

# %%
url2 = 'https://api.worldbank.org/v2/country/all/indicator/SP.DYN.LE00.IN'
params = {
    'format' : 'json'}

response2 = requests.get(url2, params = params)
response2
# Out:
# <Response [200]>

# %%
spdyn = pd.json_normalize(response2.json()[1])
spdyn = spdyn.drop(columns = ['unit', 'obs_status', 'decimal'])
spdyn
# Out:
#    countryiso3code  date      value    indicator.id  \
# 0              AFE  2023        NaN  SP.DYN.LE00.IN
# 1              AFE  2022  62.888463  SP.DYN.LE00.IN
# 2              AFE  2021  62.449093  SP.DYN.LE00.IN
# 3              AFE  2020  63.309794  SP.DYN.LE00.IN
# 4              AFE  2019  63.754752  SP.DYN.LE00.IN
# 5              AFE  2018  63.367037  SP.DYN.LE00.IN
# 6              AFE  2017  62.924810  SP.DYN.LE00.IN
# 7              AFE  2016  62.444641  SP.DYN.LE00.IN
# 8              AFE  2015  61.856856  SP.DYN.LE00.IN
# 9              AFE  2014  61.338813  SP.DYN.LE00.IN
# 10             AFE  2013  60.710028  SP.DYN.LE00.IN
# 11             AFE  2012  60.051527  SP.DYN.LE00.IN
# 12             AFE  2011  59.293319  SP.DYN.LE00.IN
# 13             AFE  2010  58.410316  SP.DYN.LE00.IN
# 14             AFE  2009  57.621514  SP.DYN.LE00.IN
# 15             AFE  2008  56.680737  SP.DYN.LE00.IN
# 16             AFE  2007  55.937838  SP.DYN.LE00.IN
# 17             AFE  2006  55.157719  SP.DYN.LE00.IN
# 18             AFE  2005  54.222950  SP.DYN.LE00.IN
# 19             AFE  2004  53.551882  SP.DYN.LE00.IN
# 20             AFE  2003  53.036301  SP.DYN.LE00.IN
# 21             AFE  2002  52.562781  SP.DYN.LE00.IN
# 22             AFE  2001  52.212239  SP.DYN.LE00.IN
# 23             AFE  2000  51.986989  SP.DYN.LE00.IN
# 24             AFE  1999  51.258874  SP.DYN.LE00.IN
# 25             AFE  1998  50.327107  SP.DYN.LE00.IN
# 26             AFE  1997  50.981970  SP.DYN.LE00.IN
# 27             AFE  1996  50.819345  SP.DYN.LE00.IN
# 28             AFE  1995  51.016037  SP.DYN.LE00.IN
# 29             AFE  1994  50.916390  SP.DYN.LE00.IN
# 30             AFE  1993  50.287942  SP.DYN.LE00.IN
# 31             AFE  1992  49.974469  SP.DYN.LE00.IN
# 32             AFE  1991  50.416060  SP.DYN.LE00.IN
# 33             AFE  1990  50.642664  SP.DYN.LE00.IN
# 34             AFE  1989  50.721001  SP.DYN.LE00.IN
# 35             AFE  1988  49.374531  SP.DYN.LE00.IN
# 36             AFE  1987  50.115386  SP.DYN.LE00.IN
# 37             AFE  1986  49.711445  SP.DYN.LE00.IN
# 38             AFE  1985  49.080274  SP.DYN.LE00.IN
# 39             AFE  1984  48.715995  SP.DYN.LE00.IN
# 40             AFE  1983  48.758163  SP.DYN.LE00.IN
# 41             AFE  1982  50.332663  SP.DYN.LE00.IN
# 42             AFE  1981  50.082623  SP.DYN.LE00.IN
# 43             AFE  1980  49.654914  SP.DYN.LE00.IN
# 44             AFE  1979  49.276900  SP.DYN.LE00.IN
# 45             AFE  1978  48.781896  SP.DYN.LE00.IN
# 46             AFE  1977  48.656762  SP.DYN.LE00.IN
# 47             AFE  1976  48.373473  SP.DYN.LE00.IN
# 48             AFE  1975  47.792879  SP.DYN.LE00.IN
# 49             AFE  1974  47.634362  SP.DYN.LE00.IN
#
#                             indicator.value country.id  \
# 0   Life expectancy at birth, total (years)         ZH
# 1   Life expectancy at birth, total (years)         ZH
# 2   Life expectancy at birth, total (years)         ZH
# 3   Life expectancy at birth, total (years)         ZH
# 4   Life expectancy at birth, total (years)         ZH
# 5   Life expectancy at birth, total (years)         ZH
# 6   Life expectancy at birth, total (years)         ZH
# 7   Life expectancy at birth, total (years)         ZH
# 8   Life expectancy at birth, total (years)         ZH
# 9   Life expectancy at birth, total (years)         ZH
# 10  Life expectancy at birth, total (years)         ZH
# 11  Life expectancy at birth, total (years)         ZH
# 12  Life expectancy at birth, total (years)         ZH
# 13  Life expectancy at birth, total (years)         ZH
# 14  Life expectancy at birth, total (years)         ZH
# 15  Life expectancy at birth, total (years)         ZH
# 16  Life expectancy at birth, total (years)         ZH
# 17  Life expectancy at birth, total (years)         ZH
# 18  Life expectancy at birth, total (years)         ZH
# 19  Life expectancy at birth, total (years)         ZH
# 20  Life expectancy at birth, total (years)         ZH
# 21  Life expectancy at birth, total (years)         ZH
# 22  Life expectancy at birth, total (years)         ZH
# 23  Life expectancy at birth, total (years)         ZH
# 24  Life expectancy at birth, total (years)         ZH
# 25  Life expectancy at birth, total (years)         ZH
# 26  Life expectancy at birth, total (years)         ZH
# 27  Life expectancy at birth, total (years)         ZH
# 28  Life expectancy at birth, total (years)         ZH
# 29  Life expectancy at birth, total (years)         ZH
# 30  Life expectancy at birth, total (years)         ZH
# 31  Life expectancy at birth, total (years)         ZH
# 32  Life expectancy at birth, total (years)         ZH
# 33  Life expectancy at birth, total (years)         ZH
# 34  Life expectancy at birth, total (years)         ZH
# 35  Life expectancy at birth, total (years)         ZH
# 36  Life expectancy at birth, total (years)         ZH
# 37  Life expectancy at birth, total (years)         ZH
# 38  Life expectancy at birth, total (years)         ZH
# 39  Life expectancy at birth, total (years)         ZH
# 40  Life expectancy at birth, total (years)         ZH
# 41  Life expectancy at birth, total (years)         ZH
# 42  Life expectancy at birth, total (years)         ZH
# 43  Life expectancy at birth, total (years)         ZH
# 44  Life expectancy at birth, total (years)         ZH
# 45  Life expectancy at birth, total (years)         ZH
# 46  Life expectancy at birth, total (years)         ZH
# 47  Life expectancy at birth, total (years)         ZH
# 48  Life expectancy at birth, total (years)         ZH
# 49  Life expectancy at birth, total (years)         ZH
#
#                   country.value
# 0   Africa Eastern and Southern
# 1   Africa Eastern and Southern
# 2   Africa Eastern and Southern
# 3   Africa Eastern and Southern
# 4   Africa Eastern and Southern
# 5   Africa Eastern and Southern
# 6   Africa Eastern and Southern
# 7   Africa Eastern and Southern
# 8   Africa Eastern and Southern
# 9   Africa Eastern and Southern
# 10  Africa Eastern and Southern
# 11  Africa Eastern and Southern
# 12  Africa Eastern and Southern
# 13  Africa Eastern and Southern
# 14  Africa Eastern and Southern
# 15  Africa Eastern and Southern
# 16  Africa Eastern and Southern
# 17  Africa Eastern and Southern
# 18  Africa Eastern and Southern
# 19  Africa Eastern and Southern
# 20  Africa Eastern and Southern
# 21  Africa Eastern and Southern
# 22  Africa Eastern and Southern
# 23  Africa Eastern and Southern
# 24  Africa Eastern and Southern
# 25  Africa Eastern and Southern
# 26  Africa Eastern and Southern
# 27  Africa Eastern and Southern
# 28  Africa Eastern and Southern
# 29  Africa Eastern and Southern
# 30  Africa Eastern and Southern
# 31  Africa Eastern and Southern
# 32  Africa Eastern and Southern
# 33  Africa Eastern and Southern
# 34  Africa Eastern and Southern
# 35  Africa Eastern and Southern
# 36  Africa Eastern and Southern
# 37  Africa Eastern and Southern
# 38  Africa Eastern and Southern
# 39  Africa Eastern and Southern
# 40  Africa Eastern and Southern
# 41  Africa Eastern and Southern
# 42  Africa Eastern and Southern
# 43  Africa Eastern and Southern
# 44  Africa Eastern and Southern
# 45  Africa Eastern and Southern
# 46  Africa Eastern and Southern
# 47  Africa Eastern and Southern
# 48  Africa Eastern and Southern
# 49  Africa Eastern and Southern

# %% [markdown]
# Merge the two results DataFrames together. You may want to rename or drop columns prior to merging.

# %%
# nysp = pd.merge(nygdp, spdyn,

# %% [markdown]
# You can also get more information about the available countries (region, capital city, income level classification, etc.) by using the Country API. Use this API to pull in all available data. Merge this with your other datasets. Use this to now remove the rows that correspond to regions and not countries.

# %% [markdown]
# Bonus Questions: After doing a basic request to get all records, you can attempt these exercises to get additional practice using query parameters.

# %% [markdown]
# Adjust your request so that it returns data just for the United States.

# %% [markdown]
# Adjust your request so that it returns data just for the United States for the year 2021.

# %% [markdown]
# Adjust your request so that it returns data just for the United States for the years 2000 through 2021.

# %% [markdown]
# Adjust your request so that it returns data for the United States and Canada for the years 2000 through 2021.

# %% [markdown]
# If you haven't already done so and you would like to get some additional practice using loops, use the page parameter in order to pull all records. Do not change the value of the per_page parameter. You will likely need to utilize a loop of some kind in order to pull all records.

# %% [markdown]
# The endpoint "http://api.worldbank.org/v2/indicator" will return information about all available indicators. See Indicator API Queries. Use this endpoint to find the code for the "Public Expenditure on Education (% GDP)" indicator.
